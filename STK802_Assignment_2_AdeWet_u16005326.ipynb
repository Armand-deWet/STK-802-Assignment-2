# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr
wr.filterwarnings('ignore')

# %% [markdown]
# # Exploratory Data Analysis

# %%
# import the csv to a pandas dataframe
claims_data = pd.read_csv('tdata.csv')

# %%
claims_data
# Out:
#        Claims  Beneficiaries  Female_Ratio       Age  Pens_ratio  Depen_ratio
# 0   -0.523689      -0.363988      0.318899  0.989855    1.032383     0.391036
# 1    0.315298      -0.246977     -0.231508  0.202030    0.219389     0.500474
# 2   -0.795031       0.110599      0.514212 -0.724255   -0.602059    -0.443807
# 3   -0.299548      -0.230417      0.450036 -0.257356   -0.258262    -0.823864
# 4   -0.097803       2.452158      0.705182 -0.673809   -0.592196     0.974980
# ..        ...            ...           ...       ...         ...          ...
# 370 -1.257507      -0.401702     -1.698012 -1.484174   -0.769730    -0.332469
# 371 -0.183141      -0.120775     -0.001799  0.066790   -0.119476     0.444593
# 372  0.954616      -0.377960      0.507267  1.165881    0.954888    -0.170689
# 373 -1.103864      -0.389717      0.248997 -0.527836   -0.473840     1.175189
# 374 -0.681678      -0.333499     -1.126981 -0.716742   -0.743663     0.734070
#
# [375 rows x 6 columns]

# %%
# Quick descrption of the data
df_description = claims_data.describe()
df_description
# Out:
#              Claims  Beneficiaries  Female_Ratio           Age    Pens_ratio  \
# count  3.750000e+02   3.750000e+02  3.750000e+02  3.750000e+02  3.750000e+02
# mean   8.000001e-12   5.333334e-12  3.466666e-11  4.266667e-11  1.066667e-11
# std    1.000000e+00   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.303044e+00  -4.054279e-01 -7.812375e+00 -1.484174e+00 -7.697298e-01
# 25%   -6.944330e-01  -3.614734e-01 -3.454016e-01 -6.888355e-01 -5.675381e-01
# 50%   -2.883498e-01  -2.724986e-01  4.294375e-02 -2.938495e-01 -3.167359e-01
# 75%    3.885371e-01  -8.986059e-02  4.522765e-01  3.850326e-01  1.489389e-01
# max    4.629657e+00   8.888981e+00  3.134834e+00  4.436322e+00  5.581343e+00
#
#         Depen_ratio
# count  3.750000e+02
# mean   5.333324e-12
# std    1.000000e+00
# min   -2.924139e+00
# 25%   -5.512902e-01
# 50%    7.364211e-02
# 75%    6.212822e-01
# max    3.266903e+00

# %%
print(df_description.to_latex())
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
#  & Claims & Beneficiaries & Female_Ratio & Age & Pens_ratio & Depen_ratio \\
# \midrule
# count & 375.000000 & 375.000000 & 375.000000 & 375.000000 & 375.000000 & 375.000000 \\
# mean & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 0.000000 \\
# std & 1.000000 & 1.000000 & 1.000000 & 1.000000 & 1.000000 & 1.000000 \\
# min & -1.303044 & -0.405428 & -7.812375 & -1.484174 & -0.769730 & -2.924139 \\
# 25% & -0.694433 & -0.361473 & -0.345402 & -0.688835 & -0.567538 & -0.551290 \\
# 50% & -0.288350 & -0.272499 & 0.042944 & -0.293850 & -0.316736 & 0.073642 \\
# 75% & 0.388537 & -0.089861 & 0.452276 & 0.385033 & 0.148939 & 0.621282 \\
# max & 4.629657 & 8.888981 & 3.134834 & 4.436322 & 5.581343 & 3.266903 \\
# \bottomrule
# \end{tabular}

# %%
# Distribution of each feature and claim column

# %%
# Set Seaborn style
sns.set_style("darkgrid")

# Identify numerical columns
numerical_columns = claims_data.columns

# Plot distribution of each numerical feature
plt.figure(figsize=(14, len(numerical_columns) * 3))
for idx, feature in enumerate(numerical_columns, 1):
    plt.subplot(len(numerical_columns), 2, idx)
    sns.histplot(claims_data[feature], kde=True)
    plt.title(f"{feature} | Skewness: {round(claims_data[feature].skew(), 2)}")

# Adjust layout and show plots
plt.tight_layout()
plt.savefig("distributions.png", bbox_inches='tight') 
plt.show()

# %%
# Box and Whisker plot of feature

# %%
# Set Seaborn style
sns.set_style("darkgrid")

# Identify numerical columns
numerical_columns = claims_data.columns

# Plot Box and Whisker plot of each numerical feature
plt.figure(figsize=(14, len(numerical_columns) * 3))
for idx, feature in enumerate(numerical_columns, 1):
    plt.subplot(len(numerical_columns), 2, idx)
    sns.boxplot(claims_data[feature], orient='h')
    plt.title(f"{feature}")

# Adjust layout and show plots
plt.tight_layout()
plt.savefig("box_whisker.png", bbox_inches='tight') 
plt.show()

# %%
# Pair plot of features

# %%
# Set the color palette
sns.set_palette("Pastel1")

# Assuming 'df' is your DataFrame
plt.figure(figsize=(10, 6))

# Using Seaborn to create a pair plot with the specified color palette
sns.pairplot(claims_data)

plt.suptitle('Pair Plot for Claims Data')
plt.savefig("pair_plot.png", bbox_inches='tight') 
plt.show()

# %%
# Correlation Matrix of featues

# %%
plt.figure(figsize=(15, 10))

# Using Seaborn to create a heatmap
sns.heatmap(claims_data.corr(), annot=True, fmt='.2f', linewidths=2)

plt.title('Correlation Heatmap of Claims Data')
plt.savefig("heat_map.png", bbox_inches='tight') 
plt.show()
